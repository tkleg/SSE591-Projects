# %% [markdown]
# # Modules

# %%
import os
files_in_directory = os.listdir('.')
print(files_in_directory)

import sys
print(f"Python version: {sys.version}")

import math
print(f"Square root of 16: {math.sqrt(16)}")

from math import factorial
print(f"Factorial of 5: {factorial(5)}")
# Out:
# ['Basic_Python_Syntax.ipynb', 'Built-In-Scalar-Types.ipynb', 'Built_In_Data_Structures.ipynb', 'Control_Flow_Statements.ipynb', 'Defining_Functions.ipynb', 'Errors_Exceptions.ipynb', 'Generators_And_Generator_Expressions.ipynb', 'How_To_Run_Python_Code.ipynb', 'Introduction.ipynb', 'Iterators.ipynb', 'List_Comprehensions.ipynb', 'Modules_And_Packages.ipynb', 'Python_Semantics_Operators.ipynb', 'Python_Semantics_Variables.ipynb']
# Python version: 3.13.14 (tags/v3.13.14:fd17997, Jun 10 2026, 13:03:48) [MSC v.1944 64 bit (AMD64)]
# Square root of 16: 4.0
# Factorial of 5: 120
