# %% [markdown]
# # Numerical Types

# %%
int_X = 1
float_X = 1.0
complex_X = 1 + 1j

print(f"int_X: {int_X}, type: {type(int_X)}")
print(f"float_X: {float_X}, type: {type(float_X)}")
print(f"complex_X: {complex_X}, type: {type(complex_X)}")
# Out:
# int_X: 1, type: <class 'int'>
# float_X: 1.0, type: <class 'float'>
# complex_X: (1+1j), type: <class 'complex'>

# %% [markdown]
# # Others

# %%
bool_X = True
str_X = "Hello, World!"
none_X = None
print(f"bool_X: {bool_X}, type: {type(bool_X)}")
print(f"str_X: {str_X}, type: {type(str_X)}")
print(f"none_X: {none_X}, type: {type(none_X)}")
# Out:
# bool_X: True, type: <class 'bool'>
# str_X: Hello, World!, type: <class 'str'>
# none_X: None, type: <class 'NoneType'>

# %% [markdown]
# # Floating-point numbers

# %%
print(0.25 + 0.75 == 1)
print(0.1 + 0.2 == 0.3)
# Out:
# True
# False

# %% [markdown]
# # Complex

# %%
c = 1 + 2.5j
print(f"c: {c}, type: {type(c)}")
print(f"Real part: {c.real}, Imaginary part: {c.imag}")
print(f"Conjugate: {c.conjugate()}")
print(f"abs(c): {abs(c)}")
# Out:
# c: (1+2.5j), type: <class 'complex'>
# Real part: 1.0, Imaginary part: 2.5
# Conjugate: (1-2.5j)
# abs(c): 2.692582403567252

# %% [markdown]
# # String

# %%
s = "Hello, World!"
print(f"s: {s}, type: {type(s)}")
print(f"Length of s: {len(s)}")
print(f"Uppercase: {s.upper()}, Lowercase: {s.lower()}")
# Out:
# s: Hello, World!, type: <class 'str'>
# Length of s: 13
# Uppercase: HELLO, WORLD!, Lowercase: hello, world!

# %% [markdown]
# # Booleans

# %%
b = True
print(f"b: {b}, type: {type(b)}")
print(f"bool of 0: {bool(0)}, bool of 1: {bool(1)}")
# Out:
# b: True, type: <class 'bool'>
# bool of 0: False, bool of 1: True
# Size of int: 28 bytes

# %%
print(bool(0), bool(1), bool(-1), bool([]), bool([1]), bool(""), bool("Hello"))
# Out:
# False True True False True False True
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
