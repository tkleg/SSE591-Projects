# %%
# Running via Jupyter Notebook

x = 5

print(f"x is {x}")

# Ran by running the cell or entire notebook.
# Out:
# x is 5

# %% [markdown]
# # Running Via the Interpreter

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Running via IPython

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Running Via a Script

# %% [markdown]
# ![image.png](attachment:image.png)
