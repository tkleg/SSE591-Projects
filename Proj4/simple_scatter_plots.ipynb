# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

plt.style.use('seaborn-v0_8-darkgrid')

# %% [markdown]
# # Scatter plots with plt.plot

# %%
x = np.linspace(-10, 10, 50)
plt.figure(figsize=(4, 3))
plt.plot(x, np.log(x), 'o')
# Out:
# C:\Users\thkle\AppData\Local\Temp\ipykernel_27824\2982318605.py:3: RuntimeWarning: invalid value encountered in log
#   plt.plot(x, np.log(x), 'o')

# %%
plt.figure(figsize=(4, 3))
plt.plot(x, np.log(x), '-o')
# Out:
# C:\Users\thkle\AppData\Local\Temp\ipykernel_27824\1431680417.py:2: RuntimeWarning: invalid value encountered in log
#   plt.plot(x, np.log(x), '-o')

# %% [markdown]
# # scatter plots with plt.scatter

# %%
plt.figure(figsize=(4, 3))
plt.scatter(x, np.log(x))
# Out:
# C:\Users\thkle\AppData\Local\Temp\ipykernel_27824\4100106420.py:2: RuntimeWarning: invalid value encountered in log
#   plt.scatter(x, np.log(x))

# %%
x = np.random.rand(100)
y = np.random.rand(100)
colors = np.random.rand(100)
sizes = np.random.rand(100)
plt.figure(figsize=(6, 4))
plt.scatter(x, y, c=colors, s=sizes*1000, alpha=0.5, cmap='viridis')
plt.colorbar()

# %%
taxis = sns.load_dataset('taxis')
taxis.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[us]
#  1   dropoff          6433 non-null   datetime64[us]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   str
#  9   payment          6389 non-null   str
#  10  pickup_zone      6407 non-null   str
#  11  dropoff_zone     6388 non-null   str
#  12  pickup_borough   6407 non-null   str
#  13  dropoff_borough  6388 non-null   str
# dtypes: datetime64[us](2), float64(5), int64(1), str(6)
# memory usage: 1.1 MB

# %%
plt.xlabel('Distance')
plt.ylabel('Total')
plt.scatter(taxis.distance, taxis.total, c=taxis.color, s= 30 * taxis.passengers, alpha=0.5)

# %% [markdown]
# plt.scatter renders each point seperately, which takes more time. plt.plt renders the points as copies, so it is faster. However, plt.scatter allows for more customization of the points, such as color and size.
